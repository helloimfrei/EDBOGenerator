# %%
import pandas as pd
from edbogenerator import EDBOGenerator

# %% [markdown]
# ## Run Initialization
# - Create a run object (example_run) for us to perform actions on
# - Initialize required directory and files if missing (components and logging)

# %%
example_run = EDBOGenerator(run_dir='example_run')
# Out:
# run directory did not exist, created one
# logging file (summary.json) generated in run directory
# components.csv file did not exist, created a template. run successfully initialized

# %% [markdown]
# The components template file looks like this. Here, the reaction scope is defined through the component columns (base, temperature, catalyst, etc.), and the run objectives are defined in the min/max columns (maximize desired_product, minimize byproducts 1,2 etc.). Update this file manually or programmatically to include the reaction components and options you want to include

# %%
dummy_components = pd.read_csv('components.csv')
dummy_components
# Out:
#   component_1 component_2 component_3 component_x    min    max
# 0           a           e           i           m  obj_1  obj_3
# 1           b           f           j           n  obj_2    NaN
# 2         NaN           g           k           o    NaN    NaN
# 3         NaN           h         NaN           p    NaN    NaN

# %%
#Updating programmatically for this example, but probably easier to do in the csv directly
#Let's say we're attempting to optimize a Buchwald
updated_components = pd.DataFrame({
            'base':['K3PO4','Cs2CO3','',''],
            'catalyst':['RuPhos Pd G4','XPhos Pd G3','XantPhos Pd G4','JackiePhos Pd G3'],
            'temperature':['80','100','120',''],
            'solvent':['THF','NMP','dioxane','toluene'],
            'min':['dehalogenation_pdt','hydrolyis_pdt','',''],
            'max':['desired_pdt','','','']
        })
updated_components.to_csv('components.csv', index = False)
updated_components
# Out:
#      base          catalyst temperature  solvent                 min  \
# 0   K3PO4      RuPhos Pd G4          80      THF  dehalogenation_pdt
# 1  Cs2CO3       XPhos Pd G3         100      NMP       hydrolyis_pdt
# 2            XantPhos Pd G4         120  dioxane
# 3          JackiePhos Pd G3              toluene
#
#            max
# 0  desired_pdt
# 1
# 2
# 3

# %% [markdown]
# ## Scope Initialization
# - Generate a combinatorial scope of the defined reaction components
# - Perform one empty round of optimization to generate a 'round_0' file that is ready for data input

# %%
#Run this every time you start a new session (even if you already have a few rounds of prediction)
example_run.initialize_scope(batch_size=5)
# Out:
# Generating reaction scope...
# scope successfully initialized
# The following columns are categorical and will be encoded using One-Hot-Encoding: ['base', 'catalyst', 'solvent']
# Sampling type:  selection
#
#
# Number of unique samples returned by sampling algorithm: 5
# Creating a priority list using random sampling: cvtsampling
# no round_0 file found,a new one was successfully generated. ready for data input!

# %% [markdown]
# The round_0 file looks like this:
# - The priority column summarizes which condition set (row) is 'high priority' and should be explored based on the underlying EDBO+ algorithm

# %%
round_0 = pd.read_csv('example_run_round_0.csv')
round_0
#Total number of rows in round_0 file matches the number of combinations of components. Nice!
# Out:
#       base          catalyst  temperature  solvent dehalogenation_pdt  \
# 0    K3PO4      RuPhos Pd G4        100.0      THF            PENDING
# 1   Cs2CO3      RuPhos Pd G4        100.0  dioxane            PENDING
# 2   Cs2CO3       XPhos Pd G3        100.0  toluene            PENDING
# 3   Cs2CO3       XPhos Pd G3        100.0  dioxane            PENDING
# 4    K3PO4       XPhos Pd G3        100.0  dioxane            PENDING
# ..     ...               ...          ...      ...                ...
# 91   K3PO4    XantPhos Pd G4        100.0  toluene            PENDING
# 92   K3PO4    XantPhos Pd G4        100.0  dioxane            PENDING
# 93   K3PO4    XantPhos Pd G4        100.0      NMP            PENDING
# 94   K3PO4    XantPhos Pd G4        100.0      THF            PENDING
# 95  Cs2CO3  JackiePhos Pd G3        120.0  toluene            PENDING
#
#    hydrolyis_pdt desired_pdt  priority
# 0        PENDING     PENDING         1
# 1        PENDING     PENDING         1
# 2        PENDING     PENDING         1
# 3        PENDING     PENDING         1
# 4        PENDING     PENDING         1
# ..           ...         ...       ...
# 91       PENDING     PENDING         0
# 92       PENDING     PENDING         0
# 93       PENDING     PENDING         0
# 94       PENDING     PENDING         0
# 95       PENDING     PENDING         0
#
# [96 rows x 8 columns]

# %% [markdown]
# ## Optimization Time!
# Several options here:
# - We can perform a standard single round of prediction by inputting a batch of experimental results into round_x.csv (typical usage)
# - We can also perform bulk data input from a training csv, which can be useful if you have existing experimental data you would like to include in the optimization
# - Finally, we can run a simulated optimizaton with a full set of experimental results. This can be useful if you want to validate the predictive ability of the algorithm before running a real optimization
#
# Each of these have methods associated with them, and all required file generation/logging is handled automatically

# %%
#Single round prediction. Begin at round 0 (or the highest round number in run directory if you began optimiation previously)

#For this example, I will programmatically insert dummy data representing percent conversion to desired product/byproducts
# You can also edit the csv directly if you prefer
import numpy as np
round_0 = pd.read_csv('example_run_round_0.csv')
round_0.iloc[0:5,4:7] = np.random.rand(5,3)
round_0.to_csv('example_run_round_0.csv',index = False)
round_0
# Out:
#       base          catalyst  temperature  solvent dehalogenation_pdt  \
# 0    K3PO4      RuPhos Pd G4        100.0      THF           0.523781
# 1   Cs2CO3      RuPhos Pd G4        100.0  dioxane           0.070229
# 2   Cs2CO3       XPhos Pd G3        100.0  toluene            0.14946
# 3   Cs2CO3       XPhos Pd G3        100.0  dioxane           0.204286
# 4    K3PO4       XPhos Pd G3        100.0  dioxane           0.342003
# ..     ...               ...          ...      ...                ...
# 91   K3PO4    XantPhos Pd G4        100.0  toluene            PENDING
# 92   K3PO4    XantPhos Pd G4        100.0  dioxane            PENDING
# 93   K3PO4    XantPhos Pd G4        100.0      NMP            PENDING
# 94   K3PO4    XantPhos Pd G4        100.0      THF            PENDING
# 95  Cs2CO3  JackiePhos Pd G3        120.0  toluene            PENDING
#
#    hydrolyis_pdt desired_pdt  priority
# 0       0.254522    0.595685         1
# 1       0.055544    0.522639         1
# 2       0.097818    0.173855         1
# 3       0.454851    0.763389         1
# 4       0.030445    0.461793         1
# ..           ...         ...       ...
# 91       PENDING     PENDING         0
# 92       PENDING     PENDING         0
# 93       PENDING     PENDING         0
# 94       PENDING     PENDING         0
# 95       PENDING     PENDING         0
#
# [96 rows x 8 columns]

# %% [markdown]
# We can then run a round of optimization using these newly inputted results:

# %%
example_run.single_round_predict(round_num=0,batch_size=5)
# Out:
# The following columns are categorical and will be encoded using One-Hot-Encoding: ['base', 'catalyst', 'solvent']
# Using EHVI acquisition function.
# Using hyperparameters optimized for continuous variables.
# Using hyperparameters optimized for continuous variables.
# Using hyperparameters optimized for continuous variables.
# Number of QMC samples using SobolQMCNormalSampler sampler: 512
# Acquisition function optimized.
# Predictions obtained and expected improvement obtained.
# optimization successful! next round (round_1) is ready for data input

# %% [markdown]
# Success!! Upon completion of a round, a new file is created titled 'pred_{run_name}_round_x.csv' containing prediction data:
# - {objective_name}_predicted_mean: the predicted value for this run objective for the condition set in the given row
# - {objective_name}_predicted_variance: the predicted variance associated with the above predicted mean, for the condition set in the given row
# - {objective_name}_expected_improvement: the expected improvement calculated by the underlying acquisition function of the EDBO+ optimizer, used in selecting the next batch of experiments to perform

# %%
round_0_preds = pd.read_csv('pred_example_run_round_0.csv')
round_0_preds
# Out:
#       base          catalyst  temperature  solvent   dehalogenation_pdt  \
# 0    K3PO4    XantPhos Pd G4         80.0      NMP              PENDING
# 1    K3PO4      RuPhos Pd G4        120.0      THF              PENDING
# 2    K3PO4      RuPhos Pd G4         80.0  dioxane              PENDING
# 3   Cs2CO3    XantPhos Pd G4        120.0  toluene              PENDING
# 4   Cs2CO3  JackiePhos Pd G3        120.0  toluene              PENDING
# ..     ...               ...          ...      ...                  ...
# 91   K3PO4       XPhos Pd G3        100.0  dioxane  0.34200316086645866
# 92   K3PO4      RuPhos Pd G4        100.0      THF   0.5237810685604164
# 93  Cs2CO3       XPhos Pd G3        100.0  toluene  0.14945996485504986
# 94  Cs2CO3       XPhos Pd G3        100.0  dioxane  0.20428604232558834
# 95  Cs2CO3      RuPhos Pd G4        100.0  dioxane  0.07022934401956693
#
#            hydrolyis_pdt          desired_pdt  priority  \
# 0                PENDING              PENDING       1.0
# 1                PENDING              PENDING       1.0
# 2                PENDING              PENDING       1.0
# 3                PENDING              PENDING       1.0
# 4                PENDING              PENDING       1.0
# ..                   ...                  ...       ...
# 91  0.030444653178705927  0.46179339668255515      -1.0
# 92    0.2545222900760834   0.5956854741775429      -1.0
# 93   0.09781775249704106   0.1738548570443399      -1.0
# 94   0.45485115629775963   0.7633893597062874      -1.0
# 95  0.055543848222394776   0.5226392204017225      -1.0
#
#     dehalogenation_pdt_predicted_mean  dehalogenation_pdt_predicted_variance  \
# 0                            0.258225                               1.082743
# 1                            0.258353                               1.082743
# 2                            0.258187                               1.082743
# 3                            0.257951                               1.082743
# 4                            0.257950                               1.082743
# ..                                ...                                    ...
# 91                           0.332528                               0.055586
# 92                           0.439764                               0.064210
# 93                           0.180995                               0.053911
# 94                           0.175167                               0.039787
# 95                           0.158049                               0.050749
#
#     dehalogenation_pdt_expected_improvement  hydrolyis_pdt_predicted_mean  \
# 0                                  1.038050                      0.178612
# 1                                  1.038121                      0.178623
# 2                                  1.038028                      0.178601
# 3                                  1.037896                      0.178609
# 4                                  1.037895                      0.178609
# ..                                      ...                           ...
# 91                                 0.402761                      0.176006
# 92                                 0.509994                      0.179157
# 93                                 0.251586                      0.174023
# 94                                 0.245419                      0.192475
# 95                                 0.228709                      0.172427
#
#     hydrolyis_pdt_predicted_variance  hydrolyis_pdt_expected_improvement  \
# 0                           1.006348                            0.911805
# 1                           1.006348                            0.911811
# 2                           1.006348                            0.911799
# 3                           1.006348                            0.911804
# 4                           1.006348                            0.911804
# ..                               ...                                 ...
# 91                          0.090483                            0.217899
# 92                          0.120216                            0.235023
# 93                          0.107868                            0.224302
# 94                          0.080666                            0.229077
# 95                          0.097377                            0.217850
#
#     desired_pdt_predicted_mean  desired_pdt_predicted_variance  \
# 0                     0.503382                        1.269464
# 1                     0.503422                        1.269464
# 2                     0.503450                        1.269464
# 3                     0.503236                        1.269465
# 4                     0.503234                        1.269464
# ..                         ...                             ...
# 91                    0.528223                        0.091664
# 92                    0.528360                        0.123836
# 93                    0.387732                        0.125644
# 94                    0.533039                        0.081778
# 95                    0.545370                        0.099240
#
#     desired_pdt_expected_improvement
# 0                           0.888189
# 1                           0.888207
# 2                           0.888220
# 3                           0.888122
# 4                           0.888121
# ..                               ...
# 91                          0.008657
# 92                          0.022720
# 93                          0.007450
# 94                          0.005887
# 95                          0.013661
#
# [96 rows x 17 columns]

# %% [markdown]
# From here, repeat single rounds of optimization as needed until desired reaction outcome is observed (or give up and try a different reaction ha ha ha.....)
#
# Or, say you forgot to input your existing experimental results before starting the optimization run.
# - Using the bulk input method, you can insert bulk training data mid-run! Simply specify the round you want to continue from (round 1 in our case)
# - This method takes a training dataframe in a similar format as your round_0 file, with columns for each reaction component, and min/max columns for run objectives (priority column not needed)
# - Names of components/run objectives need to match exactly! Take caution.

# %%
#Let's make a dummy training dataframe
training_df = round_0.copy().drop(columns=['priority']).iloc[71:95,]
training_df.iloc[:,4:7] = np.random.rand(24,3)
training_df.temperature = training_df.temperature.astype(str)
training_df
# Out:
#      base          catalyst temperature  solvent  dehalogenation_pdt  \
# 71  K3PO4      RuPhos Pd G4        80.0  dioxane            0.919483
# 72  K3PO4    XantPhos Pd G4        80.0      THF            0.149448
# 73  K3PO4    XantPhos Pd G4        80.0      NMP            0.615560
# 74  K3PO4    XantPhos Pd G4        80.0  dioxane            0.807319
# 75  K3PO4    XantPhos Pd G4        80.0  toluene            0.069167
# 76  K3PO4  JackiePhos Pd G3       120.0  dioxane            0.722056
# 77  K3PO4  JackiePhos Pd G3       120.0      NMP            0.855803
# 78  K3PO4  JackiePhos Pd G3       120.0      THF            0.729991
# 79  K3PO4  JackiePhos Pd G3       100.0  toluene            0.054338
# 80  K3PO4  JackiePhos Pd G3       100.0  dioxane            0.793698
# 81  K3PO4  JackiePhos Pd G3       100.0      NMP            0.928081
# 82  K3PO4  JackiePhos Pd G3       100.0      THF            0.164694
# 83  K3PO4  JackiePhos Pd G3        80.0  toluene            0.237893
# 84  K3PO4  JackiePhos Pd G3        80.0  dioxane            0.535633
# 85  K3PO4  JackiePhos Pd G3        80.0      NMP            0.311945
# 86  K3PO4  JackiePhos Pd G3        80.0      THF            0.186193
# 87  K3PO4    XantPhos Pd G4       120.0  toluene            0.490459
# 88  K3PO4    XantPhos Pd G4       120.0  dioxane            0.058029
# 89  K3PO4    XantPhos Pd G4       120.0      NMP            0.696343
# 90  K3PO4    XantPhos Pd G4       120.0      THF            0.024679
# 91  K3PO4    XantPhos Pd G4       100.0  toluene            0.453697
# 92  K3PO4    XantPhos Pd G4       100.0  dioxane            0.990339
# 93  K3PO4    XantPhos Pd G4       100.0      NMP            0.263322
# 94  K3PO4    XantPhos Pd G4       100.0      THF            0.320017
#
#     hydrolyis_pdt  desired_pdt
# 71       0.714241     0.998847
# 72       0.868126     0.162493
# 73       0.123820     0.848008
# 74       0.569101     0.407183
# 75       0.697429     0.453543
# 76       0.866382     0.975522
# 77       0.011714     0.359978
# 78       0.171630     0.521037
# 79       0.199997     0.018522
# 80       0.223925     0.345352
# 81       0.704414     0.031839
# 82       0.621478     0.577229
# 83       0.934214     0.613966
# 84       0.589910     0.730122
# 85       0.398221     0.209844
# 86       0.944372     0.739551
# 87       0.227415     0.254356
# 88       0.434417     0.311796
# 89       0.377752     0.179604
# 90       0.067250     0.679393
# 91       0.536579     0.896671
# 92       0.216897     0.663078
# 93       0.020651     0.758379
# 94       0.383464     0.588317

# %%
#Run the bulk data input at the specified round in the run (most recent round usually). batch_size here just indicated the batch_size desired for next round
example_run.bulk_training(training_df=training_df,round_num=1,batch_size=5)
# Out:
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "NMP"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "NMP"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "THF"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "THF"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "THF"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "dioxane"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "120.0" & solvent == "toluene"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "THF"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "80.0" & solvent == "toluene"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "NMP"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "THF"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "100.0" & solvent == "toluene"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "NMP"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "THF"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "XantPhos Pd G4" & temperature == "120.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "dioxane"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "80.0" & solvent == "NMP"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "80.0" & solvent == "toluene"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "NMP"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "THF"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "dioxane"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "100.0" & solvent == "toluene"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "toluene"
# data from training df successfully filled for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "THF"
# no matching row in training df for query: base == "K3PO4" & catalyst == "JackiePhos Pd G3" & temperature == "120.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "THF"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "80.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "dioxane"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "toluene"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "NMP"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "120.0" & solvent == "dioxane"
# no matching row in training df for query: base == "K3PO4" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "dioxane"
# no matching row in training df for query: base == "K3PO4" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "THF"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "toluene"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "XPhos Pd G3" & temperature == "100.0" & solvent == "dioxane"
# no matching row in training df for query: base == "Cs2CO3" & catalyst == "RuPhos Pd G4" & temperature == "100.0" & solvent == "dioxane"
# bulk data input successful! example_run_round_1.csv was overwritten and a backup was stored in C:\Users\Christian\EDBOGenerator\examples\example_run\backup

# %% [markdown]
# Success!! Results from training df are filled and priorities are correctly set. We're now ready for more rounds of prediction

# %%
pd.read_csv('example_run_round_1.csv').tail(30)
# Out:
#       base          catalyst  temperature  solvent   dehalogenation_pdt  \
# 46  Cs2CO3       XPhos Pd G3        120.0  dioxane              PENDING
# 47  Cs2CO3    XantPhos Pd G4         80.0      THF              PENDING
# 48  Cs2CO3    XantPhos Pd G4         80.0      NMP              PENDING
# 49  Cs2CO3      RuPhos Pd G4        120.0  toluene              PENDING
# 50  Cs2CO3    XantPhos Pd G4         80.0  dioxane              PENDING
# 51  Cs2CO3    XantPhos Pd G4         80.0  toluene              PENDING
# 52  Cs2CO3    XantPhos Pd G4        100.0      THF              PENDING
# 53  Cs2CO3  JackiePhos Pd G3        100.0      THF              PENDING
# 54  Cs2CO3    XantPhos Pd G4        100.0  dioxane              PENDING
# 55  Cs2CO3    XantPhos Pd G4        100.0  toluene              PENDING
# 56  Cs2CO3    XantPhos Pd G4        120.0      NMP              PENDING
# 57  Cs2CO3       XPhos Pd G3         80.0      NMP              PENDING
# 58  Cs2CO3      RuPhos Pd G4        120.0      NMP              PENDING
# 59  Cs2CO3      RuPhos Pd G4        120.0  dioxane              PENDING
# 60  Cs2CO3  JackiePhos Pd G3        120.0      NMP              PENDING
# 61  Cs2CO3  JackiePhos Pd G3         80.0      NMP              PENDING
# 62  Cs2CO3  JackiePhos Pd G3         80.0      THF              PENDING
# 63  Cs2CO3  JackiePhos Pd G3         80.0  dioxane              PENDING
# 64  Cs2CO3  JackiePhos Pd G3         80.0  toluene              PENDING
# 65  Cs2CO3  JackiePhos Pd G3        100.0      NMP              PENDING
# 66   K3PO4  JackiePhos Pd G3        120.0  toluene              PENDING
# 67   K3PO4  JackiePhos Pd G3        120.0      THF    0.729990562424058
# 68   K3PO4  JackiePhos Pd G3        120.0      NMP    0.855803342392611
# 69   K3PO4    XantPhos Pd G4         80.0      NMP   0.6155595642838442
# 70   K3PO4       XPhos Pd G3        100.0  dioxane  0.34200316086645866
# 71   K3PO4      RuPhos Pd G4        100.0      THF   0.5237810685604164
# 72  Cs2CO3       XPhos Pd G3        100.0  toluene  0.14945996485504986
# 73  Cs2CO3       XPhos Pd G3        100.0  dioxane  0.20428604232558834
# 74   K3PO4  JackiePhos Pd G3        100.0  dioxane   0.7936977033574206
# 75   K3PO4  JackiePhos Pd G3        100.0  toluene  0.05433798833925363
# 76   K3PO4  JackiePhos Pd G3         80.0      NMP  0.31194499547960186
# 77   K3PO4  JackiePhos Pd G3        100.0      THF  0.16469415649791275
# 78   K3PO4    XantPhos Pd G4        100.0  dioxane   0.9903389473967044
# 79   K3PO4      RuPhos Pd G4         80.0  dioxane   0.9194826137446735
# 80   K3PO4  JackiePhos Pd G3         80.0      THF  0.18619300588033616
# 81   K3PO4    XantPhos Pd G4         80.0      THF  0.14944830465799375
# 82   K3PO4    XantPhos Pd G4         80.0  dioxane   0.8073189587250107
# 83   K3PO4    XantPhos Pd G4         80.0  toluene  0.06916699545513805
# 84   K3PO4    XantPhos Pd G4        100.0      NMP  0.26332237673715064
# 85   K3PO4    XantPhos Pd G4        100.0      THF  0.32001715082246784
# 86   K3PO4    XantPhos Pd G4        100.0  toluene   0.4536968445560453
# 87   K3PO4  JackiePhos Pd G3        100.0      NMP   0.9280812934655909
# 88   K3PO4    XantPhos Pd G4        120.0      NMP   0.6963434888154595
# 89   K3PO4    XantPhos Pd G4        120.0      THF  0.02467872839133123
# 90   K3PO4    XantPhos Pd G4        120.0  dioxane  0.05802916032387562
# 91   K3PO4    XantPhos Pd G4        120.0  toluene   0.4904588086175671
# 92   K3PO4  JackiePhos Pd G3        120.0  dioxane   0.7220555994703479
# 93   K3PO4  JackiePhos Pd G3         80.0  dioxane   0.5356328030249583
# 94   K3PO4  JackiePhos Pd G3         80.0  toluene  0.23789282137450862
# 95  Cs2CO3      RuPhos Pd G4        100.0  dioxane  0.07022934401956693
#
#            hydrolyis_pdt          desired_pdt  priority
# 46               PENDING              PENDING       0.0
# 47               PENDING              PENDING       0.0
# 48               PENDING              PENDING       0.0
# 49               PENDING              PENDING       0.0
# 50               PENDING              PENDING       0.0
# 51               PENDING              PENDING       0.0
# 52               PENDING              PENDING       0.0
# 53               PENDING              PENDING       0.0
# 54               PENDING              PENDING       0.0
# 55               PENDING              PENDING       0.0
# 56               PENDING              PENDING       0.0
# 57               PENDING              PENDING       0.0
# 58               PENDING              PENDING       0.0
# 59               PENDING              PENDING       0.0
# 60               PENDING              PENDING       0.0
# 61               PENDING              PENDING       0.0
# 62               PENDING              PENDING       0.0
# 63               PENDING              PENDING       0.0
# 64               PENDING              PENDING       0.0
# 65               PENDING              PENDING       0.0
# 66               PENDING              PENDING       0.0
# 67   0.17162967726144052   0.5210366062041293      -1.0
# 68  0.011714084185001972   0.3599780644783639      -1.0
# 69   0.12381998284944151   0.8480082293222344      -1.0
# 70  0.030444653178705927  0.46179339668255515      -1.0
# 71    0.2545222900760834   0.5956854741775429      -1.0
# 72   0.09781775249704106   0.1738548570443399      -1.0
# 73   0.45485115629775963   0.7633893597062874      -1.0
# 74   0.22392468806038013   0.3453516806969027      -1.0
# 75   0.19999652489640007  0.01852179446061397      -1.0
# 76    0.3982210622160919  0.20984374897512215      -1.0
# 77    0.6214784014997635   0.5772285886041676      -1.0
# 78   0.21689698439847394   0.6630782031001008      -1.0
# 79    0.7142412995491114   0.9988470065678665      -1.0
# 80    0.9443723899839336   0.7395507950492876      -1.0
# 81    0.8681260573682142  0.16249293467637482      -1.0
# 82    0.5691007386145933  0.40718329722599966      -1.0
# 83    0.6974287731445636  0.45354268267806885      -1.0
# 84   0.02065099946572868   0.7583786538361414      -1.0
# 85   0.38346389417189797   0.5883171135536057      -1.0
# 86    0.5365792111087222   0.8966712930403421      -1.0
# 87    0.7044144019235328  0.03183892953130785      -1.0
# 88    0.3777518392924809   0.1796036775596348      -1.0
# 89   0.06724963146324858   0.6793927734985673      -1.0
# 90    0.4344166255581208   0.3117958819941026      -1.0
# 91   0.22741462797332324  0.25435648177039294      -1.0
# 92    0.8663823259286292   0.9755215050028858      -1.0
# 93     0.589909976354571   0.7301220295167696      -1.0
# 94    0.9342139979247938    0.613965955965896      -1.0
# 95  0.055543848222394776   0.5226392204017225      -1.0

# %% [markdown]
# ## Planned features
# - Built-in visualization methods to examine optimization success/when to stop optimizing
# - A UI, negating the need to edit csv's directly
# - Optimization summary generation
# - Better logging
#
# For now, logging is stored as {run_name}_summary.json in the run directory. It is persistent between sessions, so you can pickup where you left off as long as you re-run intialize_scope() (which will see that you have an existing scope and load existing components/objectives accordingly)
# - Log is organized as a dict of dicts. Each entry is an action performed during the optimization run
# - Each entry contains information regarding what action was taken (timestamp, method name, params, and result)
# - A more refined logging approach is planned

# %%
#Access logs like this:
example_run.summary
# Out:
# {0: {'timestamp': '2024-08-18 21:10:36',
#   'method': 'initialize_scope',
#   'params': {'batch_size': 5, 'kwargs': {}},
#   'result': None},
#  1: {'timestamp': '2024-08-18 21:11:47',
#   'method': 'single_round_predict',
#   'params': {'round_num': 0, 'batch_size': 5, 'kwargs': {}},
#   'result': None},
#  2: {'timestamp': '2024-08-18 21:24:41',
#   'method': 'bulk_training',
#   'params': {'training_df': {'base': {71: 'K3PO4',
#      72: 'K3PO4',
#      73: 'K3PO4',
#      74: 'K3PO4',
#      75: 'K3PO4',
#      76: 'K3PO4',
#      77: 'K3PO4',
#      78: 'K3PO4',
#      79: 'K3PO4',
#      80: 'K3PO4',
#      81: 'K3PO4',
#      82: 'K3PO4',
#      83: 'K3PO4',
#      84: 'K3PO4',
#      85: 'K3PO4',
#      86: 'K3PO4',
#      87: 'K3PO4',
#      88: 'K3PO4',
#      89: 'K3PO4',
#      90: 'K3PO4',
#      91: 'K3PO4',
#      92: 'K3PO4',
#      93: 'K3PO4',
#      94: 'K3PO4'},
#     'catalyst': {71: 'RuPhos Pd G4',
#      72: 'XantPhos Pd G4',
#      73: 'XantPhos Pd G4',
#      74: 'XantPhos Pd G4',
#      75: 'XantPhos Pd G4',
#      76: 'JackiePhos Pd G3',
#      77: 'JackiePhos Pd G3',
#      78: 'JackiePhos Pd G3',
#      79: 'JackiePhos Pd G3',
#      80: 'JackiePhos Pd G3',
#      81: 'JackiePhos Pd G3',
#      82: 'JackiePhos Pd G3',
#      83: 'JackiePhos Pd G3',
#      84: 'JackiePhos Pd G3',
#      85: 'JackiePhos Pd G3',
#      86: 'JackiePhos Pd G3',
#      87: 'XantPhos Pd G4',
#      88: 'XantPhos Pd G4',
#      89: 'XantPhos Pd G4',
#      90: 'XantPhos Pd G4',
#      91: 'XantPhos Pd G4',
#      92: 'XantPhos Pd G4',
#      93: 'XantPhos Pd G4',
#      94: 'XantPhos Pd G4'},
#     'temperature': {71: 80.0,
#      72: 80.0,
#      73: 80.0,
#      74: 80.0,
#      75: 80.0,
#      76: 120.0,
#      77: 120.0,
#      78: 120.0,
#      79: 100.0,
#      80: 100.0,
#      81: 100.0,
#      82: 100.0,
#      83: 80.0,
#      84: 80.0,
#      85: 80.0,
#      86: 80.0,
#      87: 120.0,
#      88: 120.0,
#      89: 120.0,
#      90: 120.0,
#      91: 100.0,
#      92: 100.0,
#      93: 100.0,
#      94: 100.0},
#     'solvent': {71: 'dioxane',
#      72: 'THF',
#      73: 'NMP',
#      74: 'dioxane',
#      75: 'toluene',
#      76: 'dioxane',
#      77: 'NMP',
#      78: 'THF',
#      79: 'toluene',
#      80: 'dioxane',
#      81: 'NMP',
#      82: 'THF',
#      83: 'toluene',
#      84: 'dioxane',
#      85: 'NMP',
#      86: 'THF',
#      87: 'toluene',
#      88: 'dioxane',
#      89: 'NMP',
#      90: 'THF',
#      91: 'toluene',
#      92: 'dioxane',
#      93: 'NMP',
#      94: 'THF'},
#     'dehalogenation_pdt': {71: 0.039187792254320675,
#      72: 0.29614019752214493,
#      73: 0.41426299451466997,
#      74: 0.5666014542065752,
#      75: 0.09394051075844168,
#      76: 0.31856895245132366,
#      77: 0.7163272041185655,
#      78: 0.5865129348100832,
#      79: 0.004695476192547066,
#      80: 0.7351940221225949,
#      81: 0.5761573344178369,
#      82: 0.2230816326406183,
#      83: 0.8464086724711278,
#      84: 0.8137978197024772,
#      85: 0.5812728726358587,
#      86: 0.7252542798196405,
#      87: 0.6439901992296374,
#      88: 0.019193198309333526,
#      89: 0.29007760721044407,
#      90: 0.13547406422245023,
#      91: 0.5908727612481732,
#      92: 0.6521032700016889,
#      93: 0.36756187004789653,
#      94: 0.8061939890460857},
#     'hydrolyis_pdt': {71: 0.2828069625764096,
#      72: 0.11872771895424405,
#      73: 0.06414749634878436,
#      74: 0.2653894909394454,
#      75: 0.5759464955561793,
#      76: 0.6674103799636817,
#      77: 0.2894060929472011,
#      78: 0.020107546187493552,
#      79: 0.6778165367962301,
#      80: 0.9621885451174382,
#      81: 0.592041931271839,
#      82: 0.952749011516985,
#      83: 0.6994792753175043,
#      84: 0.39650574084698464,
#      85: 0.8817353618548528,
#      86: 0.5013243819267023,
#      87: 0.4238550485581797,
#      88: 0.30157481667454933,
#      89: 0.6180154289988415,
#      90: 0.29828232595603077,
#      91: 0.5743252488495788,
#      92: 0.43141843543397396,
#      93: 0.4358649252656268,
#      94: 0.7038885835403663},
#     'desired_pdt': {71: 0.1201965612131689,
#      72: 0.317983179393976,
#      73: 0.6924721193700198,
#      74: 0.5232480534666997,
#      75: 0.9292961975762141,
#      76: 0.13179786240439217,
#      77: 0.18319136200711683,
#      78: 0.8289400292173631,
#      79: 0.27000797319216485,
#      80: 0.24875314351995803,
#      81: 0.5722519057908734,
#      82: 0.44712537861762736,
#      83: 0.29743695085513366,
#      84: 0.8811031971111616,
#      85: 0.6925315900777659,
#      86: 0.9560836347232239,
#      87: 0.6063932141279244,
#      88: 0.660173537492685,
#      89: 0.42876870094576613,
#      90: 0.5699649107012649,
#      91: 0.6532008198571336,
#      92: 0.896546595851063,
#      93: 0.8919233550156721,
#      94: 0.10022688731230112}},
#    'round_num': 1,
#    'batch_size': 5,
#    'priority_limiting': False,
#    'priority_setting': False},
#   'result': None},
#  3: {'timestamp': '2024-08-18 21:44:46',
#   'method': 'bulk_training',
#   'params': {'training_df': {'base': {71: 'K3PO4',
#      72: 'K3PO4',
#      73: 'K3PO4',
#      74: 'K3PO4',
#      75: 'K3PO4',
#      76: 'K3PO4',
#      77: 'K3PO4',
#      78: 'K3PO4',
#      79: 'K3PO4',
#      80: 'K3PO4',
#      81: 'K3PO4',
#      82: 'K3PO4',
#      83: 'K3PO4',
#      84: 'K3PO4',
#      85: 'K3PO4',
#      86: 'K3PO4',
#      87: 'K3PO4',
#      88: 'K3PO4',
#      89: 'K3PO4',
#      90: 'K3PO4',
#      91: 'K3PO4',
#      92: 'K3PO4',
#      93: 'K3PO4',
#      94: 'K3PO4'},
#     'catalyst': {71: 'RuPhos Pd G4',
#      72: 'XantPhos Pd G4',
#      73: 'XantPhos Pd G4',
#      74: 'XantPhos Pd G4',
#      75: 'XantPhos Pd G4',
#      76: 'JackiePhos Pd G3',
#      77: 'JackiePhos Pd G3',
#      78: 'JackiePhos Pd G3',
#      79: 'JackiePhos Pd G3',
#      80: 'JackiePhos Pd G3',
#      81: 'JackiePhos Pd G3',
#      82: 'JackiePhos Pd G3',
#      83: 'JackiePhos Pd G3',
#      84: 'JackiePhos Pd G3',
#      85: 'JackiePhos Pd G3',
#      86: 'JackiePhos Pd G3',
#      87: 'XantPhos Pd G4',
#      88: 'XantPhos Pd G4',
#      89: 'XantPhos Pd G4',
#      90: 'XantPhos Pd G4',
#      91: 'XantPhos Pd G4',
#      92: 'XantPhos Pd G4',
#      93: 'XantPhos Pd G4',
#      94: 'XantPhos Pd G4'},
#     'temperature': {71: '80.0',
#      72: '80.0',
#      73: '80.0',
#      74: '80.0',
#      75: '80.0',
#      76: '120.0',
#      77: '120.0',
#      78: '120.0',
#      79: '100.0',
#      80: '100.0',
#      81: '100.0',
#      82: '100.0',
#      83: '80.0',
#      84: '80.0',
#      85: '80.0',
#      86: '80.0',
#      87: '120.0',
#      88: '120.0',
#      89: '120.0',
#      90: '120.0',
#      91: '100.0',
#      92: '100.0',
#      93: '100.0',
#      94: '100.0'},
#     'solvent': {71: 'dioxane',
#      72: 'THF',
#      73: 'NMP',
#      74: 'dioxane',
#      75: 'toluene',
#      76: 'dioxane',
#      77: 'NMP',
#      78: 'THF',
#      79: 'toluene',
#      80: 'dioxane',
#      81: 'NMP',
#      82: 'THF',
#      83: 'toluene',
#      84: 'dioxane',
#      85: 'NMP',
#      86: 'THF',
#      87: 'toluene',
#      88: 'dioxane',
#      89: 'NMP',
#      90: 'THF',
#      91: 'toluene',
#      92: 'dioxane',
#      93: 'NMP',
#      94: 'THF'},
#     'dehalogenation_pdt': {71: 0.9194826137446735,
#      72: 0.14944830465799375,
#      73: 0.6155595642838442,
#      74: 0.8073189587250107,
#      75: 0.06916699545513805,
#      76: 0.7220555994703479,
#      77: 0.855803342392611,
#      78: 0.729990562424058,
#      79: 0.05433798833925363,
#      80: 0.7936977033574206,
#      81: 0.9280812934655909,
#      82: 0.16469415649791275,
#      83: 0.23789282137450862,
#      84: 0.5356328030249583,
#      85: 0.31194499547960186,
#      86: 0.18619300588033616,
#      87: 0.4904588086175671,
#      88: 0.05802916032387562,
#      89: 0.6963434888154595,
#      90: 0.02467872839133123,
#      91: 0.4536968445560453,
#      92: 0.9903389473967044,
#      93: 0.26332237673715064,
#      94: 0.32001715082246784},
#     'hydrolyis_pdt': {71: 0.7142412995491114,
#      72: 0.8681260573682142,
#      73: 0.12381998284944151,
#      74: 0.5691007386145933,
#      75: 0.6974287731445636,
#      76: 0.8663823259286292,
#      77: 0.011714084185001972,
#      78: 0.17162967726144052,
#      79: 0.19999652489640007,
#      80: 0.22392468806038013,
#      81: 0.7044144019235328,
#      82: 0.6214784014997635,
#      83: 0.9342139979247938,
#      84: 0.589909976354571,
#      85: 0.3982210622160919,
#      86: 0.9443723899839336,
#      87: 0.22741462797332324,
#      88: 0.4344166255581208,
#      89: 0.3777518392924809,
#      90: 0.06724963146324858,
#      91: 0.5365792111087222,
#      92: 0.21689698439847394,
#      93: 0.02065099946572868,
#      94: 0.38346389417189797},
#     'desired_pdt': {71: 0.9988470065678665,
#      72: 0.16249293467637482,
#      73: 0.8480082293222344,
#      74: 0.40718329722599966,
#      75: 0.45354268267806885,
#      76: 0.9755215050028858,
#      77: 0.3599780644783639,
#      78: 0.5210366062041293,
#      79: 0.01852179446061397,
#      80: 0.3453516806969027,
#      81: 0.03183892953130785,
#      82: 0.5772285886041676,
#      83: 0.613965955965896,
#      84: 0.7301220295167696,
#      85: 0.20984374897512215,
#      86: 0.7395507950492876,
#      87: 0.25435648177039294,
#      88: 0.3117958819941026,
#      89: 0.1796036775596348,
#      90: 0.6793927734985673,
#      91: 0.8966712930403421,
#      92: 0.6630782031001008,
#      93: 0.7583786538361414,
#      94: 0.5883171135536057}},
#    'round_num': 1,
#    'batch_size': 5,
#    'priority_limiting': False,
#    'priority_setting': False},
#   'result': None}}

# %% [markdown]
# ## Thanks for sticking around! Always happy to chat, feel free to reach out with any suggestions/questions.
